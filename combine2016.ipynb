# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanawich-Pinprayoon/Dog-and-Cat-Lab-test-to-medicine-recommendation/blob/master/combine2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                                   **2016**

# %% [markdown]
# #Import + get permission

# %%
import os 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# #get Data

# %%
Lab_df = pd.read_csv('/content/drive/My Drive/ThaiWordcutTest/doc/csv/2016/ANTIMICROBIALS_2016_GN.csv')

# %%
AST_df = pd.read_csv('/content/drive/My Drive/ThaiWordcutTest/doc/csv/2016/AST_2016_GN.csv')

# %% [markdown]
# #COMBINE BOTH FILE TO ONE

# %% [markdown]
# ##define med list from Get_ALL_GN_MED.ipynb

# %%
drug_list = [ 
#  A
 'Amikacin',
 'Ampicillin',
 'Amoxicillin/clavulanic acid',
#  B
#  C
 'Cefixime',
 'Cefovecin',
 'Cefpodoxime',
 'Ceftiofur',
 'Ceftriaxone',
 'Cephalexin',
 'Chloramphenicol',
 'Colistin (polymyxin E)',
#  D
 'Doxycycline',
#  E
 'ESBL',
 'Enrofloxacin',
#  F
 'Fosfomycin',
#  G
 'Gentamicin',
#  H
#  I
 'Imipenem',
#  J
#  K
#  L
#  M
 'Marbofloxacin',
#  N
 'Nitrofurantoin',
#  O
#  P
 'Piperacillin-tazobactam',
 'Polymyxin B',
#  Q
#  R
 'Rifampin',
#  S
 'Sulfamethoxazole/trimethoprim',
#  T
 'Tetracycline',
 'Tobramycin',
 ]

# %%
class Case:
  def __init__(self,id = None):
    self.id = id
    # if id = None:
    #   self.id = -1
    # else:
    #   self.id = id

    # if list == None:
    self.list = []
    for _list in drug_list:
      self._list = None
    # GP
    # self.Ampicillin = None
    # self.Amoxicillinclavulanicacid = None
    # self.Piperacillin = None
    # self.Cephalexin = None
    # self.Cefpodoxime = None
    # self.Cefovecin = None
    # self.Ceftiofur = None
    # self.Imipenem = None
    # self.Amikacin = None
    # self.Gentamicin = None
    # self.Tobramycin = None
    # self.Enrofloxacin = None
    # self.Marbofloxacin = None
    # self.Tetracycline = None
    # self.Nitrofurantoin = None
    # self.Chloramphenicol = None
    # self.PolymyxinB = None
    # self.Rifampin = None
    # self.Sulfamethoxazoletrimethoprim = None
    # self.ESBL = None
    for __i in drug_list:
      self.list.append("NA")
  def makeList(self):
    list = []
    for _list in drug_list:
      list.append(self._list)

    # GP
    # list.append(self.Ampicillin)
    # list.append(self.Amoxicillinclavulanicacid)
    # list.append(self.Piperacillin)
    # list.append(self.Cephalexin)
    # list.append(self.Cefpodoxime)
    # list.append(self.Cefovecin)
    # list.append(self.Ceftiofur)
    # list.append(self.Imipenem)
    # list.append(self.Amikacin)
    # list.append(self.Gentamicin)
    # list.append(self.Tobramycin)
    # list.append(self.Enrofloxacin)
    # list.append(self.Marbofloxacin)
    # list.append(self.Tetracycline)
    # list.append(self.Nitrofurantoin)
    # list.append(self.Chloramphenicol)
    # list.append(self.PolymyxinB)
    # list.append(self.Rifampin)
    # list.append(self.Sulfamethoxazoletrimethoprim)
    # list.append(self.ESBL)

  def set_id(self,id):
    self.id = id
  
  def __str__(self):
    return str(self.id)

# %%
def getCol(drugName):
  drugName = str(drugName)
  if drugName[-1] == " ":
    drugName = drugName.strip()
  if drugName == 'Amoxicillin/clavulanic':
    drugName = 'Amoxicillin/clavulanic acid'
  elif drugName == 'Amoxicillin':
    drugName = 'Amoxicillin/clavulanic acid'
  elif drugName == 'Piperacillin':
    drugName = 'Piperacillin-tazobactam'
  elif drugName == 'Cefalexin':
    drugName = 'Cephalexin'
  elif drugName ==  'Polymixin B':
    drugName = 'Polymyxin B'
  for index_drugList in range(len(drug_list)):
    # print(drugName,drug_list[index_drugList])
    if drugName == drug_list[index_drugList]:
      return int(index_drugList)
   
  print('================================================================')
  print('      ERROR : drug name : ',drugName,' NOT FOUND!')
  print('================================================================')
  drug_not_found.append(drugName)
  return None

# %%
cases = []
ids_list = []
drug_not_found = []
for index_Lab in range(len(Lab_df['id'])):
  # print(index_Lab)
  #dropped 0
  if index_Lab == 0:
    continue
  
  #make class
  this_id = int(Lab_df['id'].loc[index_Lab])
  #print('id = ',this_id,end=" ")
  if this_id not in ids_list:
    while this_id != len(cases)-1:
      cases.append(Case(index_Lab))
    print("cases size = ", len(cases))
    ids_list.append(this_id)
    print(' this id = ',this_id)

  #get drug name
  drug_name = Lab_df['anti_name'].loc[index_Lab]
  print('name : ',drug_name)

  #find col of the drug
  sel_col = getCol(drug_name)
  if sel_col == None:
    # break
    continue
  print('col = ',sel_col)

  #put result
  # print('   make list ',index_Lab)
  cases[this_id].makeList()
  cases[this_id].list[sel_col] = Lab_df['sir'].loc[index_Lab]
  # print('   -end make list ',index_Lab)
  # print(len(cases[this_id].list))
  print("==============================")
# Out:
# Streaming output truncated to the last 5000 lines.
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  141
#  this id =  140
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  142
#  this id =  141
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  143
#  this id =  142
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  144
#  this id =  143
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  145
#  this id =  144
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  146
#  this id =  145
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  147
#  this id =  146
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  148
#  this id =  147
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  149
#  this id =  148
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  150
#  this id =  149
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  151
#  this id =  150
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  152
#  this id =  151
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  153
#  this id =  152
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  154
#  this id =  153
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  155
#  this id =  154
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  156
#  this id =  155
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  157
#  this id =  156
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  158
#  this id =  157
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  159
#  this id =  158
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  160
#  this id =  159
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  161
#  this id =  160
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  162
#  this id =  161
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  163
#  this id =  162
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  164
#  this id =  163
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  165
#  this id =  164
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  166
#  this id =  165
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  167
#  this id =  166
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymyxin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  168
#  this id =  167
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  169
#  this id =  168
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  170
#  this id =  169
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  171
#  this id =  170
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  172
#  this id =  171
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  173
#  this id =  172
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  174
#  this id =  173
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  175
#  this id =  174
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  176
#  this id =  175
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  177
#  this id =  176
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  178
#  this id =  177
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# ...
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  209
#  this id =  208
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  210
#  this id =  209
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  211
#  this id =  210
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  212
#  this id =  211
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  213
#  this id =  212
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  214
#  this id =  213
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  215
#  this id =  214
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  216
#  this id =  215
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  217
#  this id =  216
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  218
#  this id =  217
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  219
#  this id =  218
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  220
#  this id =  219
# name :  ESBL
# col =  12
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================
# cases size =  221
#  this id =  220
# name :  ESBL
# col =  12
# ==============================
# name :  Ampicillin
# col =  1
# ==============================
# name :  Amoxicillin/clavulanic acid
# col =  2
# ==============================
# name :  Piperacillin
# col =  19
# ==============================
# name :  Cefalexin
# col =  8
# ==============================
# name :  Cefpodoxime
# col =  5
# ==============================
# name :  Cefovecin
# col =  4
# ==============================
# name :  Ceftiofur
# col =  6
# ==============================
# name :  Imipenem
# col =  16
# ==============================
# name :  Amikacin
# col =  0
# ==============================
# name :  Gentamicin
# col =  15
# ==============================
# name :  Tobramycin
# col =  24
# ==============================
# name :  Enrofloxacin
# col =  13
# ==============================
# name :  Marbofloxacin
# col =  17
# ==============================
# name :  Tetracycline
# col =  23
# ==============================
# name :  Nitrofurantoin
# col =  18
# ==============================
# name :  Chloramphenicol
# col =  9
# ==============================
# name :  Polymixin B
# col =  20
# ==============================
# name :  Rifampin
# col =  21
# ==============================
# name :  Sulfamethoxazole/trimethoprim
# col =  22
# ==============================

# %%
drug_not_found
# Out:
# ['R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'nan',
#  '>=320',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'R',
#  '>=32',
#  '16',
#  '8',
#  '16',
#  '<=0.25',
#  '<=0.5',
#  '<=1',
#  'nan',
#  '<=2',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  '<=2',
#  '<=0.25',
#  '<=1',
#  '<=1',
#  '<=1',
#  '<=0.25',
#  '<=20',
#  '16',
#  '8',
#  '<=1',
#  '>=16',
#  '>=16',
#  '>=16',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  '*R',
#  '*R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'nan',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'S',
#  'nan',
#  'S',
#  '<=16',
#  '<=2',
#  'nan',
#  'nan',
#  '<=20',
#  'Disk diffusion test : AMC(S) DO(S) ENR(S) GN(S) SXT(R) AK(S) EFT(R)',
#  'R',
#  'S',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'R',
#  'nan',
#  '>=320',
#  'nan',
#  '>=320',
#  'R',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'R',
#  'R',
#  'R',
#  'R',
#  'S',
#  'S',
#  'R',
#  '<=16',
#  '<=2',
#  'S',
#  '4',
#  '>=8',
#  '<=1',
#  '<=1',
#  '>=16',
#  '0.5',
#  '<=20',
#  'R',
#  'R']

# %%
len(cases)
# Out:
# 221

# %%
cases[44].list[2]
# Out:
# 'I'

# %%
combined_df = AST_df

# %%
combined_columns = ['id','species','submitted_sample','collect_method','vitek_id','bact_species_1']
for _drug in drug_list:
  combined_columns.append(_drug)
print(combined_columns)
# Out:
# ['id', 'species', 'submitted_sample', 'collect_method', 'vitek_id', 'bact_species_1', 'Amikacin', 'Ampicillin', 'Amoxicillin/clavulanic acid', 'Cefixime', 'Cefovecin', 'Cefpodoxime', 'Ceftiofur', 'Ceftriaxone', 'Cephalexin', 'Chloramphenicol', 'Colistin (polymyxin E)', 'Doxycycline', 'ESBL', 'Enrofloxacin', 'Fosfomycin', 'Gentamicin', 'Imipenem', 'Marbofloxacin', 'Nitrofurantoin', 'Piperacillin-tazobactam', 'Polymyxin B', 'Rifampin', 'Sulfamethoxazole/trimethoprim', 'Tetracycline', 'Tobramycin']

# %%
# combined_df = combined_df.drop(columns=['hn']) 
combined_df = combined_df.drop(columns=['clinician'])
combined_df = combined_df.drop(columns=['collect_date'])
combined_df = combined_df.drop(columns=['submit_date'])
combined_df = combined_df.drop(columns=['owner'])
combined_df = combined_df.drop(columns=['patient'])
combined_df = combined_df.drop(columns=['breed'])
combined_df = combined_df.drop(columns=['sex'])
combined_df = combined_df.drop(columns=['birth_date'])
combined_df = combined_df.drop(columns=['lot_no'])
combined_df = combined_df.drop(columns=['vitek_ast'])
combined_df = combined_df.drop(columns=['bact_species_2'])
combined_df = combined_df.drop(columns=['read_date'])
combined_df = combined_df.drop(columns=['reader'])
combined_df = combined_df.drop(columns=['recommendation'])
combined_df = combined_df.drop(columns=['file_name'])

# %%
combined_df

# %%
for index_drug_list in range(len(drug_list)):
  #list to store sir in col
  colDrug = []
  #collect sir result from cases
  for index_cases in range(len(cases)):
    colDrug.append(cases[index_cases].list[index_drug_list])
  combined_df[drug_list[index_drug_list]] = colDrug

# %%
combined_df

# %%
species_list = combined_df['species']
species_list
# Out:
# 0      Dog
# 1      Dog
# 2      Dog
# 3        C
# 4        C
#       ...
# 216    Dog
# 217    Cat
# 218    Dog
# 219    NaN
# 220    Cat
# Name: species, Length: 221, dtype: object

# %%
for specie_index in range(len(species_list)):
  if species_list[specie_index] == 'C':
    species_list[specie_index] = 'Dog'
  elif species_list[specie_index] == 'F':
    species_list[specie_index] = 'Cat'
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
species_list
# Out:
# 0      Dog
# 1      Dog
# 2      Dog
# 3      Dog
# 4      Dog
#       ...
# 216    Dog
# 217    Cat
# 218    Dog
# 219    NaN
# 220    Cat
# Name: species, Length: 221, dtype: object

# %%
combined_df

# %%
combined_df.to_csv('/content/drive/My Drive/ThaiWordcutTest/doc/csv/2016/2016_combined_GN.csv', encoding='utf-8', index = False)
