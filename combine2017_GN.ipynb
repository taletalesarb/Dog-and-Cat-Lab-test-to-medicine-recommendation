# %% [markdown]
# <a href="https://colab.research.google.com/github/Thanawich-Pinprayoon/Dog-and-Cat-Lab-test-to-medicine-recommendation/blob/master/combine2017_GN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #                                   **2017**

# %% [markdown]
# #Import + get permission

# %%
import os 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# #get Data

# %%
Lab_df = pd.read_csv('/content/drive/My Drive/ThaiWordcutTest/doc/csv/2017/ANTIMICROBIALS_2017_GN.csv')

# %%
AST_df = pd.read_csv('/content/drive/My Drive/ThaiWordcutTest/doc/csv/2017/AST_2017_GN.csv')

# %% [markdown]
# #COMBINE BOTH FILE TO ONE

# %% [markdown]
# ##define med list from Get_ALL_GN_MED.ipynb

# %%
drug_list = [ 
 'amikacin',
 'amoxicillin/clavulanic acid',
 'ampicillin',
 'benzylpenicillin',
 'cefalexin',
#  'cephalexin',
 'cefalotin',
#  'cephalothin',
#  'cefalothin',
 'cefovecin',
 'cefoxitin',
 'cefpodoxime',
 'ceftiofur',
 'chloramphenicol',
 'clindamycin',
 'doxycycline',
 'enrofloxacin',
 'erythromycin',
 'esbl',
 'fusidic acid',
 'gentamicin',
 'imipenem',
 'inducible clindamycin',
 'marbofloxacin',
 'mupirocin',
 'neomycin',
 'nitrofurantoin',
 'oxacillin',
 'piperacillin',
#  'polymixin b',
 'polymyxin b',
 'pradofloxacin',
 'rifampin',
 #  'rifampicin',
 'sulfamethoxazole/trimethoprim',
 'tetracycline',
 'tobramycin',
 'vancomycin'
 ]

# %%
len(drug_list)
# Out:
# 33

# %%
class Case:
  def __init__(self,id = None):
    self.id = id
    # if id = None:
    #   self.id = -1
    # else:
    #   self.id = id

    # if list == None:
    self.list = []
    for _list in drug_list:
      self._list = None
    for __i in drug_list:
      self.list.append("NA")
  def makeList(self):
    list = []
    for _list in drug_list:
      list.append(self._list)
  def set_id(self,id):
    self.id = id
  
  def __str__(self):
    return str(self.id)

# %%
def getCol(drugName):
  drugName = str(drugName).lower()
  if drugName[-1] == " ":
    drugName = drugName.strip()
  if drugName == 'amoxicillin/clavulanic':
    drugName = 'amoxicillin/clavulanic acid'
  elif drugName == 'amoxicillin':
    drugName = 'amoxicillin/clavulanic acid'
  elif drugName == 'piperacillin-tazobactam':
    drugName = 'piperacillin'
  elif drugName ==  'polymixin b':
    drugName = 'polymyxin b'
  elif drugName == 'amoxy/clav':
    drugName = 'amoxicillin/clavulanic acid'
  elif drugName == 'cephalothin':
    drugName = 'cefalotin'
  elif drugName == 'cefalothin':
    drugName = 'cefalotin'
  elif drugName == 'oxacillin*':
    drugName = 'oxacillin'
  elif drugName == 'minocyclilne':
    drugName = 'minocycline'
  elif drugName == 'benzyl penicillin':
    drugName = 'benzylpenicillin'
  elif drugName == 'cephalothin':
    drugName = 'cefalotin'
  elif drugName == 'inducible clindamycin resistance':
    drugName = 'inducible clindamycin'
  elif drugName == 'cephalexin':
    drugName = 'cefalexin'
  elif drugName == 'rifampicin':
    drugName = 'rifampin'
    
  for index_drugList in range(len(drug_list)):
    # print(drugName,drug_list[index_drugList])
    if drugName == drug_list[index_drugList]:
      return int(index_drugList)
   
  print('================================================================')
  print('      ERROR : drug name : .'+str(drugName)+'. NOT FOUND!')
  print('================================================================')
  if drugName not in drug_not_found:
    drug_not_found.append(drugName)
  return None

# %%
cases = []
ids_list = []
drug_not_found = []
for index_Lab in range(len(Lab_df['id'])):
  # print(index_Lab)
  #dropped 0
  if index_Lab == 0:
    continue
  
  #make class
  this_id = int(Lab_df['id'].loc[index_Lab])
  #print('id = ',this_id,end=" ")
  if this_id not in ids_list:
    while this_id != len(cases)-1:
      cases.append(Case(index_Lab))
    # print("cases size = ", len(cases))
    ids_list.append(this_id)
    # print(' this id = ',this_id)

  #get drug name
  drug_name = Lab_df['anti_name'].loc[index_Lab]
  # print('name : ',drug_name)

  #find col of the drug
  sel_col = getCol(drug_name)
  if sel_col == None:
    # break
    continue
  # print('col = ',sel_col)

  #put result
  # print('   make list ',index_Lab)
  cases[this_id].makeList()
  cases[this_id].list[sel_col] = Lab_df['sir'].loc[index_Lab]
  # print('   -end make list ',index_Lab)
  # print(len(cases[this_id].list))
  # print("==============================")
# Out:
# ================================================================
#       ERROR : drug name : .ถ้าเป็น acinetobacter lwoffii จะมีค่า polymyxin b (0.5, s) และ rifampicin (<=2, s). NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .s. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .s. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .s. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .disk diffusion test : amox/clav (s), ceftiofur(s), enrofloxacin (s) doxycycline (s),. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .amikacin (s), amoxicillin/clavulanic acid (s), sulfamethoxazole/trim (s), enrofloxacin (s), gentamicin (s), doxycycline (s). NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .s. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .r. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .<=20. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .results of antimicrobial susceptibility testing (ast). NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .results of antimicrobial susceptibility testing (ast). NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .--. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .date of submission. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .วรจิตรา อึ้งภาภรณ์. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .species. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .bangkaew. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .birth date. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .submitted sample. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .nan. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .lot no. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .gn. NOT FOUND!
# ================================================================
# ================================================================
#       ERROR : drug name : .enterobacter cloacae complex (1.6x105 cfu/ml). NOT FOUND!
# ================================================================

# %%
drug_not_found
# Out:
# ['ถ้าเป็น acinetobacter lwoffii จะมีค่า polymyxin b (0.5, s) และ rifampicin (<=2, s)',
#  'r',
#  's',
#  'disk diffusion test : amox/clav (s), ceftiofur(s), enrofloxacin (s) doxycycline (s),',
#  'amikacin (s), amoxicillin/clavulanic acid (s), sulfamethoxazole/trim (s), enrofloxacin (s), gentamicin (s), doxycycline (s)',
#  '<=20',
#  'results of antimicrobial susceptibility testing (ast)',
#  '--',
#  'date of submission',
#  'วรจิตรา อึ้งภาภรณ์',
#  'species',
#  'bangkaew',
#  'birth date',
#  'submitted sample',
#  'nan',
#  'lot no',
#  'gn',
#  'enterobacter cloacae complex (1.6x105 cfu/ml)']

# %%
len(cases)
# Out:
# 542

# %%
cases[44].list[2]
# Out:
# 'R'

# %%
combined_df = AST_df

# %%
combined_columns = ['id','species','submitted_sample','collect_method','vitek_id','bact_species_1']
for _drug in drug_list:
  combined_columns.append(_drug)
print(combined_columns)
# Out:
# ['id', 'species', 'submitted_sample', 'collect_method', 'vitek_id', 'bact_species_1', 'amikacin', 'amoxicillin/clavulanic acid', 'ampicillin', 'benzylpenicillin', 'cefalexin', 'cefalotin', 'cefovecin', 'cefoxitin', 'cefpodoxime', 'ceftiofur', 'chloramphenicol', 'clindamycin', 'doxycycline', 'enrofloxacin', 'erythromycin', 'esbl', 'fusidic acid', 'gentamicin', 'imipenem', 'inducible clindamycin', 'marbofloxacin', 'mupirocin', 'neomycin', 'nitrofurantoin', 'oxacillin', 'piperacillin', 'polymyxin b', 'pradofloxacin', 'rifampin', 'sulfamethoxazole/trimethoprim', 'tetracycline', 'tobramycin', 'vancomycin']

# %%
# combined_df = combined_df.drop(columns=['hn']) 
combined_df = combined_df.drop(columns=['clinician'])
combined_df = combined_df.drop(columns=['collect_date'])
combined_df = combined_df.drop(columns=['submit_date'])
combined_df = combined_df.drop(columns=['owner'])
combined_df = combined_df.drop(columns=['patient'])
combined_df = combined_df.drop(columns=['breed'])
combined_df = combined_df.drop(columns=['sex'])
combined_df = combined_df.drop(columns=['birth_date'])
combined_df = combined_df.drop(columns=['lot_no'])
combined_df = combined_df.drop(columns=['vitek_ast'])
combined_df = combined_df.drop(columns=['bact_species_2'])
combined_df = combined_df.drop(columns=['read_date'])
combined_df = combined_df.drop(columns=['reader'])
combined_df = combined_df.drop(columns=['recommendation'])
combined_df = combined_df.drop(columns=['file_name'])

# %%
combined_df
# Out:
#       id  ...                                  bact_species_1
# 0      0  ...  Pseudomonas aeruginosa หรือ Pseudomonas putida
# 1      1  ...              Proteus mirabilis (4.6x107 CFU/ml)
# 2      2  ...            Klebsiella pneumoniae ssp pneumoniae
# 3      3  ...           Pseudomonas aeruginosa (1x106 CFU/ml)
# 4      4  ...                               Proteus mirabilis
# ..   ...  ...                                             ...
# 537  537  ...            Klebsiella pneumoniae ssp pneumoniae
# 538  538  ...            Klebsiella pneumoniae ssp pneumoniae
# 539  539  ...                    Stenotrophomonas maltophilia
# 540  540  ...               Escherichia coli (1.8x106 CFU/ml)
# 541  541  ...                               Proteus mirabilis
#
# [542 rows x 7 columns]

# %%
for index_drug_list in range(len(drug_list)):
  #list to store sir in col
  colDrug = []
  #collect sir result from cases
  for index_cases in range(len(cases)):
    colDrug.append(cases[index_cases].list[index_drug_list])
  combined_df[drug_list[index_drug_list]] = colDrug

# %%
combined_df
# Out:
#       id  ... vancomycin
# 0      0  ...         NA
# 1      1  ...         NA
# 2      2  ...         NA
# 3      3  ...         NA
# 4      4  ...         NA
# ..   ...  ...        ...
# 537  537  ...         NA
# 538  538  ...         NA
# 539  539  ...         NA
# 540  540  ...         NA
# 541  541  ...         NA
#
# [542 rows x 40 columns]

# %%
species_list = combined_df['species']
species_list
# Out:
# 0      Dog
# 1      Dog
# 2      Dog
# 3      Dog
# 4      Dog
#       ...
# 537    Dog
# 538    Dog
# 539    Cat
# 540    Dog
# 541    Dog
# Name: species, Length: 542, dtype: object

# %%
for specie_index in range(len(species_list)):
  if species_list[specie_index] == 'C':
    species_list[specie_index] = 'Dog'
  elif species_list[specie_index] == 'F':
    species_list[specie_index] = 'Cat'

# %%
species_list
# Out:
# 0      Dog
# 1      Dog
# 2      Dog
# 3      Dog
# 4      Dog
#       ...
# 537    Dog
# 538    Dog
# 539    Cat
# 540    Dog
# 541    Dog
# Name: species, Length: 542, dtype: object

# %%
combined_df
# Out:
#       id  ... vancomycin
# 0      0  ...         NA
# 1      1  ...         NA
# 2      2  ...         NA
# 3      3  ...         NA
# 4      4  ...         NA
# ..   ...  ...        ...
# 537  537  ...         NA
# 538  538  ...         NA
# 539  539  ...         NA
# 540  540  ...         NA
# 541  541  ...         NA
#
# [542 rows x 40 columns]

# %%
combined_df.to_csv('/content/drive/My Drive/ThaiWordcutTest/doc/csv/2017/2017_combined_GN.csv', encoding='utf-8', index = False)

# %%
len(combined_df.columns)
# Out:
# 40
